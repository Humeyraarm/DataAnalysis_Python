# %% [markdown]
# # **Handling with Missing Values**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
id_no = ["P001","P002","P003","P004","P005","P006","P007","P008","P009","P010","P011"]
gender=["M","F","M","F","M","F","M","F","M","F","M"]
status = ["FT","PT","-","FT","PT","PT","FT","-","PT","FT",np.nan]
dept = ["DS","FS","AWS","AWS","DS",np.nan,"FS","FS",np.nan,"DS","AWS"]
V1 = np.array([2,3,5,np.nan,7,1,np.nan,10,14,"-",6])
V2 = np.array([8,np.nan,5,8,11,np.nan,np.nan,2,3,7,9])
salary = np.array([np.nan,54,59,120,58,75,np.nan,136,60,125,np.nan])
df = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })
df
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 2   P003      M      -  AWS    5   5.0    59.0
# 3   P004      F     FT  AWS  nan   8.0   120.0
# 4   P005      M     PT   DS    7  11.0    58.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 7   P008      F      -   FS   10   2.0   136.0
# 8   P009      M     PT  NaN   14   3.0    60.0
# 9   P010      F     FT   DS    -   7.0   125.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 744.0+ bytes

# %%
type(np.nan)
# Out:
# float

# %%
type(np.NaN)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
df.salary
# Out:
# 0       NaN
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6       NaN
# 7     136.0
# 8      60.0
# 9     125.0
# 10      NaN
# Name: salary, dtype: float64

# %%
type(df.salary[0])
# Out:
# numpy.float64

# %%
type(df.status[2])
# Out:
# str

# %%
df.var1
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
type(df.var1[3])    #arrayde 1 str varsa arr hepsini str'e çevirir.
# Out:
# str

# %% [markdown]
# What is the None keyword in Python?
#
# https://www.educative.io/edpresso/what-is-the-none-keyword-in-python
#
# https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object
#
# Difference between None and NaN in Pandas
#
# https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas
#
# https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb
#
# Difference between np.nan and np.NaN
#
# https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan
#
# Difference between nan and 'nan' in Python
#
# https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python
#
# https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b

# %% [markdown]
# # **Detecting Missing Values**
#
# NaN, standing for not a number, is a numeric data type used to represent any value that is undefined or unpresentable.
#
# For example, 0/0 is undefined as a real number and is, therefore, represented by NaN. The square root of a negative number is an imaginary number that cannot be represented as a real number, so, it is represented by NaN.
#
# NaN is also assigned to variables, in a computation, that do not have values and have yet to be computed.

# %%
df
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 2   P003      M      -  AWS    5   5.0    59.0
# 3   P004      F     FT  AWS  nan   8.0   120.0
# 4   P005      M     PT   DS    7  11.0    58.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 7   P008      F      -   FS   10   2.0   136.0
# 8   P009      M     PT  NaN   14   3.0    60.0
# 9   P010      F     FT   DS    -   7.0   125.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df.isnull()
#df.isna()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.notnull()
#df.notna()
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.isnull().any()    #default axis=0 (sutuna bakıyor)
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %%
df.isnull().any(axis=1)  #satırlara bakıyor
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
#number of missing values in the columns

df.isnull().sum()
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %%
df.isnull().sum().sum()  #null values in all df
# Out:
# 9

# %%
df.salary.isnull().any()
# Out:
# True

# %%
df.salary.isnull().sum()
# Out:
# 3

# %%
# percentage of null values by columns

df.isnull().sum()/len(df)*100
# Out:
# id         0.000000
# gender     0.000000
# status     9.090909
# dept      18.181818
# var1       0.000000
# var2      27.272727
# salary    27.272727
# dtype: float64

# %%
# return rows having at least one missing value
df.loc[df.isnull().any(axis=1)]
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 8   P009      M     PT  NaN   14   3.0    60.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df[~df.isnull().any(axis=1)]
# Out:
#      id gender status dept var1  var2  salary
# 2  P003      M      -  AWS    5   5.0    59.0
# 3  P004      F     FT  AWS  nan   8.0   120.0
# 4  P005      M     PT   DS    7  11.0    58.0
# 7  P008      F      -   FS   10   2.0   136.0
# 9  P010      F     FT   DS    -   7.0   125.0

# %%
df[df.isnull().all(axis=1)]  #return rows have all missing value
# Out:
# Empty DataFrame
# Columns: [id, gender, status, dept, var1, var2, salary]
# Index: []

# %%
df.loc[df.salary.isnull()]
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 6   P007      M     FT   FS  nan   NaN     NaN
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %% [markdown]
# # **Converting inappropriate values to NaN values**
#
# map()
#
# replace()

# %%
df
# Out:
#       id gender status dept var1  var2  salary
# 0   P001      M     FT   DS    2   8.0     NaN
# 1   P002      F     PT   FS    3   NaN    54.0
# 2   P003      M      -  AWS    5   5.0    59.0
# 3   P004      F     FT  AWS  nan   8.0   120.0
# 4   P005      M     PT   DS    7  11.0    58.0
# 5   P006      F     PT  NaN    1   NaN    75.0
# 6   P007      M     FT   FS  nan   NaN     NaN
# 7   P008      F      -   FS   10   2.0   136.0
# 8   P009      M     PT  NaN   14   3.0    60.0
# 9   P010      F     FT   DS    -   7.0   125.0
# 10  P011      M    NaN  AWS    6   9.0     NaN

# %%
df["var1"].map({"-":np.nan})  #belirttiğimi yapar.belirtmediğim değerleri nan döndürür.
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: var1, dtype: float64

# %% [markdown]
# Notes: When arg is a dictionary, values in Series that are not in the dictionary (as keys) are converted to NaN. However, if the dictionary is a dict subclass that defines missing (i.e. provides a method for default values), then this default is used rather than NaN.

# %%
df["var1"].replace(to_replace="-",value=np.nan)  #type still object.because I fill it must be numeric
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace(to_replace="-",value=np.nan).astype(float)
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.var1
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace(to_replace=["-","nan"],value=np.nan)   #same with 45.cell
# Out:
# 0       2
# 1       3
# 2       5
# 3     NaN
# 4       7
# 5       1
# 6     NaN
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"] = df["var1"].replace("-", np.nan).astype("float")  # assign column name makes permanent

# %%
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["status"] = df["status"].replace("-", np.nan)
df["status"]
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.isnull().sum()
# Out:
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# # **Missing value handling methods**
#
# **Deleting Rows ----->**if it has more than 70-75% of missing values. This percentage can change according to the data. So each situation should be evaluated case by case.
#
# **Replacing With Mean/Median/Mode (Imputation)--->**can be applied on a feature which has numeric data
#
# **Assigning An Unique Category--->**If a categorical feature has definite number of classes, we can assign another class
#
# **Predicting The Missing Values--->** we can predict the nulls with the help of a machine learning algorithm like linear regression
#
# **Using Algorithms Which Support Missing Values--->**KNN is a machine learning algorithm which works on the principle of distance measure. This algorithm can be used when there are nulls present in the dataset. KNN considers the missing values by taking the majority of the K nearest values

# %% [markdown]
# # **Dropping**
#
# dropna()
#
# drop()

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
# it removes the rows which contains any (at least one missing value) missing value

df.dropna(axis=0, how="any", thresh=None, inplace=False)
#how : {'any','all'}, default 'any', Determine if row or column is removed from DataFrame, when we have at least one NA or all NA.
#inplace : bool, default False, If True, do operation inplace and return None.
#thresh : Require that many non-NA values.
# Out:
#      id gender status dept  var1  var2  salary
# 4  P005      M     PT   DS   7.0  11.0    58.0

# %%
# it removes the columns which contains any (at least one missing value) missing value

df.dropna(axis=1, how="any", thresh=None, inplace=False)
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %%
df.dropna(axis=1, how="all", thresh=None, inplace=False)
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %% [markdown]
# **'any' :** If any NA values are present, drop that row or column.
#
# **'all' :** If all values are NA, drop that row or column.

# %%
# Create a column containing full of missing value

df["delete_me"] = np.nan
df
# Out:
#       id gender status dept  var1  var2  salary  delete_me
# 0   P001      M     FT   DS   2.0   8.0     NaN        NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0        NaN
# 2   P003      M    NaN  AWS   5.0   5.0    59.0        NaN
# 3   P004      F     FT  AWS   NaN   8.0   120.0        NaN
# 4   P005      M     PT   DS   7.0  11.0    58.0        NaN
# 5   P006      F     PT  NaN   1.0   NaN    75.0        NaN
# 6   P007      M     FT   FS   NaN   NaN     NaN        NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0        NaN
# 8   P009      M     PT  NaN  14.0   3.0    60.0        NaN
# 9   P010      F     FT   DS   NaN   7.0   125.0        NaN
# 10  P011      M    NaN  AWS   6.0   9.0     NaN        NaN

# %%
# Drop the column containing full of missing value

df.dropna(axis = 1, how = "all", inplace = True)
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.dropna(axis=1, how="any", thresh=9, inplace=False)  
# 9ve 9 taneden fazla nan'dan farklı değer olan satırı silme
#thresh=N requires that a column has at least N non-NaNs to survive.
# Out:
#       id gender dept
# 0   P001      M   DS
# 1   P002      F   FS
# 2   P003      M  AWS
# 3   P004      F  AWS
# 4   P005      M   DS
# 5   P006      F  NaN
# 6   P007      M   FS
# 7   P008      F   FS
# 8   P009      M  NaN
# 9   P010      F   DS
# 10  P011      M  AWS

# %%
df.drop([1,3,5])   # here act as a name
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
# df.drop(["var1", "var2"]) # gives an error
df.drop(["var1", "var2"], axis=1)
# Out:
#       id gender status dept  salary
# 0   P001      M     FT   DS     NaN
# 1   P002      F     PT   FS    54.0
# 2   P003      M    NaN  AWS    59.0
# 3   P004      F     FT  AWS   120.0
# 4   P005      M     PT   DS    58.0
# 5   P006      F     PT  NaN    75.0
# 6   P007      M     FT   FS     NaN
# 7   P008      F    NaN   FS   136.0
# 8   P009      M     PT  NaN    60.0
# 9   P010      F     FT   DS   125.0
# 10  P011      M    NaN  AWS     NaN

# %%
df.drop(index=[1,3,5])
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.drop(columns=["id", "var1"])
# Out:
#    gender status dept  var2  salary
# 0       M     FT   DS   8.0     NaN
# 1       F     PT   FS   NaN    54.0
# 2       M    NaN  AWS   5.0    59.0
# 3       F     FT  AWS   8.0   120.0
# 4       M     PT   DS  11.0    58.0
# 5       F     PT  NaN   NaN    75.0
# 6       M     FT   FS   NaN     NaN
# 7       F    NaN   FS   2.0   136.0
# 8       M     PT  NaN   3.0    60.0
# 9       F     FT   DS   7.0   125.0
# 10      M    NaN  AWS   9.0     NaN

# %% [markdown]
# # **Filling Missing Values (Imputation)**
#
#
# **a.Filling with a specific value**

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.fillna(0)
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     0.0
# 1   P002      F     PT   FS   3.0   0.0    54.0
# 2   P003      M      0  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   0.0   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT    0   1.0   0.0    75.0
# 6   P007      M     FT   FS   0.0   0.0     0.0
# 7   P008      F      0   FS  10.0   2.0   136.0
# 8   P009      M     PT    0  14.0   3.0    60.0
# 9   P010      F     FT   DS   0.0   7.0   125.0
# 10  P011      M      0  AWS   6.0   9.0     0.0

# %%
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].fillna(0)
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# **b.Filling with any Proper Value**

# %%
df["var1"].mean()
# Out:
# 6.0

# %%
df["var1"].fillna(df["var1"].mean())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].median()
# Out:
# 5.5

# %%
df["var1"].fillna(df["var1"].median())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.5
# 4      7.0
# 5      1.0
# 6      5.5
# 7     10.0
# 8     14.0
# 9      5.5
# 10     6.0
# Name: var1, dtype: float64

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# var1       6.000
# var2       6.625
# salary    85.875
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#       id gender status dept  var1    var2   salary
# 0   P001      M     FT   DS   2.0   8.000   85.875
# 1   P002      F     PT   FS   3.0   6.625   54.000
# 2   P003      M    NaN  AWS   5.0   5.000   59.000
# 3   P004      F     FT  AWS   6.0   8.000  120.000
# 4   P005      M     PT   DS   7.0  11.000   58.000
# 5   P006      F     PT  NaN   1.0   6.625   75.000
# 6   P007      M     FT   FS   6.0   6.625   85.875
# 7   P008      F    NaN   FS  10.0   2.000  136.000
# 8   P009      M     PT  NaN  14.0   3.000   60.000
# 9   P010      F     FT   DS   6.0   7.000  125.000
# 10  P011      M    NaN  AWS   6.0   9.000   85.875

# %%
df.fillna({"dept":"other","var1":df.var1.mean(),"var2":df.var2.median()})
# Out:
#       id gender status   dept  var1  var2  salary
# 0   P001      M     FT     DS   2.0   8.0     NaN
# 1   P002      F     PT     FS   3.0   7.5    54.0
# 2   P003      M    NaN    AWS   5.0   5.0    59.0
# 3   P004      F     FT    AWS   6.0   8.0   120.0
# 4   P005      M     PT     DS   7.0  11.0    58.0
# 5   P006      F     PT  other   1.0   7.5    75.0
# 6   P007      M     FT     FS   6.0   7.5     NaN
# 7   P008      F    NaN     FS  10.0   2.0   136.0
# 8   P009      M     PT  other  14.0   3.0    60.0
# 9   P010      F     FT     DS   6.0   7.0   125.0
# 10  P011      M    NaN    AWS   6.0   9.0     NaN

# %%
df.mean()[["var1","var2"]]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# var1    6.000
# var2    6.625
# dtype: float64

# %%
df.fillna(df.mean()[["var1","var2"]])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#       id gender status dept  var1    var2  salary
# 0   P001      M     FT   DS   2.0   8.000     NaN
# 1   P002      F     PT   FS   3.0   6.625    54.0
# 2   P003      M    NaN  AWS   5.0   5.000    59.0
# 3   P004      F     FT  AWS   6.0   8.000   120.0
# 4   P005      M     PT   DS   7.0  11.000    58.0
# 5   P006      F     PT  NaN   1.0   6.625    75.0
# 6   P007      M     FT   FS   6.0   6.625     NaN
# 7   P008      F    NaN   FS  10.0   2.000   136.0
# 8   P009      M     PT  NaN  14.0   3.000    60.0
# 9   P010      F     FT   DS   6.0   7.000   125.0
# 10  P011      M    NaN  AWS   6.0   9.000     NaN

# %% [markdown]
# **where() Replace values where the condition is False.**

# %%
df.notna()
# Out:
#       id  gender  status   dept   var1   var2  salary
# 0   True    True    True   True   True   True   False
# 1   True    True    True   True   True  False    True
# 2   True    True   False   True   True   True    True
# 3   True    True    True   True  False   True    True
# 4   True    True    True   True   True   True    True
# 5   True    True    True  False   True  False    True
# 6   True    True    True   True  False  False   False
# 7   True    True   False   True   True   True    True
# 8   True    True    True  False   True   True    True
# 9   True    True    True   True  False   True    True
# 10  True    True   False   True   True   True   False

# %%
# df.where(pd.notna(df), df.mean(), axis = "columns")
df.where(cond=df.notna(), other=df.mean(), axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#       id gender status dept  var1    var2   salary
# 0   P001      M     FT   DS   2.0   8.000   85.875
# 1   P002      F     PT   FS   3.0   6.625   54.000
# 2   P003      M    NaN  AWS   5.0   5.000   59.000
# 3   P004      F     FT  AWS   6.0   8.000  120.000
# 4   P005      M     PT   DS   7.0  11.000   58.000
# 5   P006      F     PT  NaN   1.0   6.625   75.000
# 6   P007      M     FT   FS   6.0   6.625   85.875
# 7   P008      F    NaN   FS  10.0   2.000  136.000
# 8   P009      M     PT  NaN  14.0   3.000   60.000
# 9   P010      F     FT   DS   6.0   7.000  125.000
# 10  P011      M    NaN  AWS   6.0   9.000   85.875

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.interpolate() # Fill NaN values using an interpolation method.
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   6.5    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   6.0   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   8.0    75.0
# 6   P007      M     FT   FS   5.5   5.0   105.5
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS  10.0   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0   125.0

# %% [markdown]
# **c.Filling the Missing Values of Categorical Variables**

# %%
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT  NaN   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT  NaN  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df["dept"].mode()[0]
# Out:
# 'AWS'

# %%
df["dept"].fillna(df["dept"].mode()[0])
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df["dept"].fillna(method="bfill")
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      FS
# 6      FS
# 7      FS
# 8      DS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df["dept"].fillna(method="ffill",inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT   DS   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.loc[df["salary"]<100,"status"]
# Out:
# 1     PT
# 2    NaN
# 4     PT
# 5     PT
# 8     PT
# Name: status, dtype: object

# %%
# inplace=True didn't work with loc condition

df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0], inplace=True)
df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0], inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M    NaN  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT   DS   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F    NaN   FS  10.0   2.0   136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.loc[df["salary"]>=100, "status"] = df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0])
df.loc[df["salary"]<100, "status"] = df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0])
df
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0     NaN
# 1   P002      F     PT   FS   3.0   NaN    54.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0
# 5   P006      F     PT   DS   1.0   NaN    75.0
# 6   P007      M     FT   FS   NaN   NaN     NaN
# 7   P008      F     FT   FS  10.0   2.0   136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0
# 9   P010      F     FT   DS   NaN   7.0   125.0
# 10  P011      M    NaN  AWS   6.0   9.0     NaN

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()[0])
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %%
df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
df
# Out:
#       id gender status dept  var1  var2  salary trans_status
# 0   P001      M     FT   DS   2.0   8.0     NaN           FT
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT
# 6   P007      M     FT   FS   NaN   NaN     NaN           FT
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT
# 10  P011      M    NaN  AWS   6.0   9.0     NaN           PT

# %%
df["status"].fillna(df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0]), inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary trans_status
# 0   P001      M     FT   DS   2.0   8.0     NaN           FT
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT
# 6   P007      M     FT   FS   NaN   NaN     NaN           FT
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT
# 10  P011      M     PT  AWS   6.0   9.0     NaN           PT

# %%
#regarding to avg of "salary" in terms of "department"

df.groupby("dept")["salary"].mean()
# Out:
# dept
# AWS    89.500000
# DS     86.000000
# FS     83.333333
# Name: salary, dtype: float64

# %%
# we transformed the values of "salary" column into group average.

df.groupby("dept")["salary"].transform("mean")
# Out:
# 0     86.000000
# 1     83.333333
# 2     89.500000
# 3     89.500000
# 4     86.000000
# 5     86.000000
# 6     83.333333
# 7     83.333333
# 8     83.333333
# 9     86.000000
# 10    89.500000
# Name: salary, dtype: float64

# %%
df["salary"].fillna(df.groupby("dept")["salary"].transform("mean"))
# Out:
# 0      86.000000
# 1      54.000000
# 2      59.000000
# 3     120.000000
# 4      58.000000
# 5      75.000000
# 6      83.333333
# 7     136.000000
# 8      60.000000
# 9     125.000000
# 10     89.500000
# Name: salary, dtype: float64

# %%
df.groupby(["status","dept"])["salary"].mean()
# Out:
# status  dept
# FT      AWS     120.0
#         DS      125.0
#         FS      136.0
# PT      AWS      59.0
#         DS       66.5
#         FS       57.0
# Name: salary, dtype: float64

# %%
df.groupby(["status","dept"])["salary"].transform("mean")
# Out:
# 0     125.0
# 1      57.0
# 2      59.0
# 3     120.0
# 4      66.5
# 5      66.5
# 6     136.0
# 7     136.0
# 8      57.0
# 9     125.0
# 10     59.0
# Name: salary, dtype: float64

# %%
df["trans_salary"] = df.groupby(["status","dept"])["salary"].transform("mean")
df
# Out:
#       id gender status dept  var1  var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0     NaN           FT         125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT          59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT          66.5
# 6   P007      M     FT   FS   NaN   NaN     NaN           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT          57.0
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0     NaN           PT          59.0

# %%
df["salary"].fillna(df.groupby(["status","dept"])["salary"].transform("mean"), inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT         125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT          59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT          66.5
# 6   P007      M     FT   FS   NaN   NaN   136.0           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT          57.0
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT          59.0

# %%
df.groupby(["gender","status"])["var1"].mean()
# Out:
# gender  status
# F       FT        10.0
#         PT         2.0
# M       FT         2.0
#         PT         8.0
# Name: var1, dtype: float64

# %%
df.groupby(["gender","status"])["var1"].transform("mean")
# Out:
# 0      2.0
# 1      2.0
# 2      8.0
# 3     10.0
# 4      8.0
# 5      2.0
# 6      2.0
# 7     10.0
# 8      8.0
# 9     10.0
# 10     8.0
# Name: var1, dtype: float64

# %%
df["var1"].fillna(df.groupby(["gender","status"])["var1"].transform("mean"), inplace=True)
df
# Out:
#       id gender status dept  var1  var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT         125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT          59.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT          66.5
# 6   P007      M     FT   FS   2.0   NaN   136.0           FT         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT          57.0
# 9   P010      F     FT   DS  10.0   7.0   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT          59.0

# %%
cond = (df["gender"]=="M") & (df["status"]=="FT")
cond
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df.loc[cond, "var2"]
# Out:
# 0    8.0
# 6    NaN
# Name: var2, dtype: float64

# %%
df.loc[cond, "var2"].mode()[0]
# Out:
# 8.0

# %%
df.loc[cond, "var2"].fillna(df.loc[cond, "var2"].mode()[0])
# Out:
# 0    8.0
# 6    8.0
# Name: var2, dtype: float64

# %%
df["var2"]
# Out:
# 0      8.0
# 1      NaN
# 2      5.0
# 3      8.0
# 4     11.0
# 5      NaN
# 6      NaN
# 7      2.0
# 8      3.0
# 9      7.0
# 10     9.0
# Name: var2, dtype: float64

# %%
df.groupby("status")["var2"].transform("mean")
# Out:
# 0     6.25
# 1     7.00
# 2     7.00
# 3     6.25
# 4     7.00
# 5     7.00
# 6     6.25
# 7     6.25
# 8     7.00
# 9     6.25
# 10    7.00
# Name: var2, dtype: float64

# %%
df["var2"].fillna(df.groupby("status")["var2"].transform("mean"),inplace=True)
df
# Out:
#       id gender status dept  var1   var2  salary trans_status  trans_salary
# 0   P001      M     FT   DS   2.0   8.00   125.0           FT         125.0
# 1   P002      F     PT   FS   3.0   7.00    54.0           FT          57.0
# 2   P003      M     PT  AWS   5.0   5.00    59.0           PT          59.0
# 3   P004      F     FT  AWS  10.0   8.00   120.0           FT         120.0
# 4   P005      M     PT   DS   7.0  11.00    58.0           FT          66.5
# 5   P006      F     PT   DS   1.0   7.00    75.0           FT          66.5
# 6   P007      M     FT   FS   2.0   6.25   136.0           FT         136.0
# 7   P008      F     FT   FS  10.0   2.00   136.0           FT         136.0
# 8   P009      M     PT   FS  14.0   3.00    60.0           FT          57.0
# 9   P010      F     FT   DS  10.0   7.00   125.0           FT         125.0
# 10  P011      M     PT  AWS   6.0   9.00    59.0           PT          59.0

# %% [markdown]
# # **filling with Interpolation**
#
# Pandas dataframe.interpolate() function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value.

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
flights.passengers.plot();

# %%
df = flights.copy()

# %%
df.loc[np.random.randint(1,144,20),"passengers"] = None

# %%
df.isnull().sum()
# Out:
# year           0
# month          0
# passengers    17
# dtype: int64

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan       112.0
# 1    1949   Feb       118.0
# 2    1949   Mar       132.0
# 3    1949   Apr         NaN
# 4    1949   May       121.0
# ..    ...   ...         ...
# 139  1960   Aug       606.0
# 140  1960   Sep         NaN
# 141  1960   Oct       461.0
# 142  1960   Nov       390.0
# 143  1960   Dec       432.0
#
# [144 rows x 3 columns]

# %%
df.passengers.plot()

# %%
df["passengers"].interpolate().plot(kind="line")

# %%
df["passengers"].fillna(method="ffill").plot(kind="line")

# %%
df.passengers.plot()
